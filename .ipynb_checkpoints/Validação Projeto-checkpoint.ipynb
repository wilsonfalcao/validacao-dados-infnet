# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA 
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.cluster import DBSCAN
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 4
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
# ----> 4 from sklearn.cluster import KMeans
#       5 from sklearn.decomposition import PCA
#       6 from sklearn.preprocessing import StandardScaler
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
df_life_expec = pd.read_csv("life-expectancy.csv", sep=",",index_col=0)
df_life_expec.head(6)
# Out:
#                      Life Expectancy (years) - Men  \
# Country
# Afghanistan                                   60.6
# Albania                                       74.8
# Algeria                                       73.3
# Andorra                                       81.7
# Angola                                        58.1
# Antigua and Barbuda                           74.4
#
#                      Life Expectancy (years) - Women  Happiness Score  \
# Country
# Afghanistan                                     68.2            3.794
# Albania                                         81.3            4.959
# Algeria                                         78.9            5.605
# Andorra                                         84.8            6.955
# Angola                                          65.6            4.105
# Antigua and Barbuda                             78.9            6.102
#
#                      Fertility Rate (births per woman)
# Country
# Afghanistan                                        4.7
# Albania                                            1.7
# Algeria                                            2.9
# Andorra                                            1.4
# Angola                                             5.3
# Antigua and Barbuda                                2.2

# %%
sns.pairplot(df_life_expec)

# %%
df_life_expec_normalize = StandardScaler().fit(df_life_expec)
df_life_expec_normalize
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_life_expec_normalize = StandardScaler().fit(df_life_expec)
#       2 df_life_expec_normalize
#
# NameError: name 'StandardScaler' is not defined
